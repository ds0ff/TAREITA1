# %%
from datetime import date
from datetime import datetime
from datetime import timedelta

# %%
Nombre = input('Escriba su nombre: ')
Edad = input ('Escriba su edad: ')
Edad = int(Edad)
fecha = date.today()
nueva_fecha = fecha+timedelta(days=3652)
# Out:
# Escriba su nombre: Danna
# Escriba su edad: 16

# %%
texto1= ("{fecha2}"
    '\nQuerida {nombre}'
'\nHoy a tus {edad} se supone que ya terminaste las dos carreras, entonces deberías estar trabajando en algo,' 
         '\nojalá no sea ganando una miseria :D.'
'\nPero bueno, espero que hayas mejorado emocionalmente, que sigas con tus gatitos y quién sabe y con muchos más; '
         '\nte deseo lo mejor, porfa no te mueras antes de cumplir todo lo que querías hacer.').format(nombre=Nombre, edad=Edad+10, fecha2=nueva_fecha)
print(texto1)
# Out:
# 2032-02-15
# Querida Danna
# Hoy a tus 26 se supone que ya terminaste las dos carreras, entonces deberías estar trabajando en algo,
# ojalá no sea ganando una miseria :D.
# Pero bueno, espero que hayas mejorado emocionalmente, que sigas con tus gatitos y quién sabe y con muchos más;
# te deseo lo mejor, porfa no te mueras antes de cumplir todo lo que querías hacer.
